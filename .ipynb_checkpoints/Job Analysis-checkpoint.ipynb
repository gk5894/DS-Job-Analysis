# %%
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.util import ngrams
from nltk.util import bigrams
from nltk.collocations import *
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
da_ny = pd.read_csv('jobs_1.csv')
ba_ny = pd.read_csv('jobs_2.csv')
ds_ny = pd.read_csv('jobs_3.csv')
de_ny = pd.read_csv('jobs_4.csv')
da_bo = pd.read_csv('jobs_5.csv')
ba_bo = pd.read_csv('jobs_6.csv')
ds_bo = pd.read_csv('jobs_7.csv')
de_bo = pd.read_csv('jobs_8.csv')
da_ch = pd.read_csv('jobs_9.csv')
ba_ch = pd.read_csv('jobs_10.csv')
ds_ch = pd.read_csv('jobs_11.csv')
de_ch = pd.read_csv('jobs_12.csv')
ds_main = pd.concat([da_ny,ba_ny,ds_ny,de_ny,da_bo,ba_bo,ds_bo,de_bo,da_ch,ba_ch,ds_ch,de_ch],ignore_index=True)
#ds_main = pd.concat([da_ny,da_bo,da_ch],ignore_index=True)

# %%
ds_main.head()
len(ds_main)
# Out:
# 4307

# %%
ds_main.drop_duplicates(subset=['job_Title','company_name','summary'],inplace = True)

# %%
len(ds_main)
# Out:
# 2010

# %%
summary=ds_main['summary']

# %%
summary = summary.apply(lambda x: " ".join(x.lower() for x in x.split()))
summary = summary.str.replace('[^\w\s]','')

# %%
stop = stopwords.words('english')
summary = summary.apply(lambda x: " ".join(x for x in x.split() if x not in stop))
summary.head()
# Out:
# 0    health care data analyst collect compile organ...
# 1    knack data familiarity combining manipulating ...
# 2    financial firm nyc seeking administrative anal...
# 3    perform data loads data extracts conversions m...
# 4    looking fulltime data analyst assist large ong...
# Name: summary, dtype: object

# %%
freq = pd.Series(' '.join(summary).split()).value_counts()[:10]
freq
# Out:
# data          2545
# business      1043
# analyst        714
# experience     435
# team           314
# engineer       261
# analysis       238
# analytics      232
# years          218
# work           198
# dtype: int64

# %%
freq = pd.Series(' '.join(summary).split()).value_counts()[-10:]
freq
# Out:
# ams               1
# samples           1
# electricity       1
# nobles            1
# finalize          1
# metropolitan      1
# approval          1
# anything          1
# withsalesforce    1
# prosecutors       1
# dtype: int64

# %%
freq = list(freq.index)
summary = summary.apply(lambda x: " ".join(x for x in x.split() if x not in freq))
summary.head()
# Out:
# 0    health care data analyst collect compile organ...
# 1    knack data familiarity combining manipulating ...
# 2    financial firm nyc seeking administrative anal...
# 3    perform data loads data extracts conversions m...
# 4    looking fulltime data analyst assist large ong...
# Name: summary, dtype: object

# %%
TextBlob(summary[1]).words
# Out:
# WordList(['knack', 'data', 'familiarity', 'combining', 'manipulating', 'data', 'tables', 'data', 'sets', 'joins', 'unions', 'etc', 'construct', 'data', 'sets', 'required', 'analysis'])

# %%
TextBlob(summary[0]).ngrams(3)
# Out:
# [WordList(['health', 'care', 'data']),
#  WordList(['care', 'data', 'analyst']),
#  WordList(['data', 'analyst', 'collect']),
#  WordList(['analyst', 'collect', 'compile']),
#  WordList(['collect', 'compile', 'organize']),
#  WordList(['compile', 'organize', 'health']),
#  WordList(['organize', 'health', 'care']),
#  WordList(['health', 'care', 'data']),
#  WordList(['care', 'data', 'include']),
#  WordList(['data', 'include', 'medical']),
#  WordList(['include', 'medical', 'data']),
#  WordList(['medical', 'data', 'financial']),
#  WordList(['data', 'financial', 'data'])]

# %%
#tokens = nltk.word_tokenize(summary)
type(summary)
# Out:
# pandas.core.series.Series

# %%
docs=(summary.tolist())
summary_text = ''.join(docs)

# %%
tokens = nltk.word_tokenize(summary_text)

# %%
print(len(tokens))
# Out:
# 27157

# %%
tokens_pos_tag = nltk.pos_tag(tokens)

# %%
pos_df = pd.DataFrame(tokens_pos_tag, columns = ('word','POS'))

# %%
pos_df.head()
# Out:
#       word  POS
# 0   health   NN
# 1     care   NN
# 2     data  NNS
# 3  analyst   NN
# 4  collect  VBP

# %%
pos_sum = pos_df.groupby('POS', as_index=False).count() # group by POS tags

# %%
pos_sum.sort_values(['word'], ascending=[False]) # in descending order of number of words per tag
# Out:
#      POS   word
# 10    NN  10500
# 12   NNS   6149
# 6     JJ   4197
# 21   VBG   1979
# 23   VBP   1501
# 15    RB    634
# 2     CD    367
# 20   VBD    350
# 24   VBZ    344
# 19    VB    323
# 22   VBN    303
# 5     IN    265
# 8    JJS     65
# 9     MD     39
# 13   PRP     38
# 1     CC     23
# 7    JJR     19
# 4     FW     18
# 16   RBR     13
# 11   NNP      7
# 3     DT      7
# 18    RP      5
# 25    WP      2
# 26   WP$      2
# 0      $      2
# 27   WRB      2
# 17   RBS      2
# 14  PRP$      1

# %%
filtered_pos = [ ]

# %%
#for one in tokens_pos_tag:
#    if one[1] == 'NN' or one[1] == 'NNS' or one[1] == 'NNP' or one[1] == 'NNPS':
#        filtered_pos.append(one)

# %%
for one in tokens_pos_tag:
    if one[1] == 'NN' or one[1] == 'NNP' or one[1] == 'NNPS':
        filtered_pos.append(one)

# %%
print (len(filtered_pos))
# Out:
# 10507

# %%
fdist_pos = nltk.FreqDist(filtered_pos)

# %%
top_100_words = fdist_pos.most_common(100)

# %%
print(top_100_words)
# Out:
# [(('business', 'NN'), 876), (('analyst', 'NN'), 681), (('experience', 'NN'), 253), (('team', 'NN'), 253), (('analysis', 'NN'), 208), (('engineer', 'NN'), 178), (('machine', 'NN'), 162), (('management', 'NN'), 137), (('support', 'NN'), 134), (('science', 'NN'), 123), (('work', 'NN'), 120), (('scientist', 'NN'), 99), (('join', 'NN'), 98), (('development', 'NN'), 95), (('role', 'NN'), 92), (('process', 'NN'), 74), (('research', 'NN'), 72), (('quality', 'NN'), 72), (('software', 'NN'), 70), (('technology', 'NN'), 70), (('project', 'NN'), 68), (('information', 'NN'), 65), (('product', 'NN'), 65), (('design', 'NN'), 61), (('engineering', 'NN'), 59), (('data', 'NN'), 56), (('visualization', 'NN'), 55), (('position', 'NN'), 53), (('health', 'NN'), 51), (('detail', 'NN'), 48), (('mining', 'NN'), 46), (('intelligence', 'NN'), 45), (('knowledge', 'NN'), 45), (('ability', 'NN'), 45), (('client', 'NN'), 43), (('help', 'NN'), 37), (('attention', 'NN'), 37), (('system', 'NN'), 36), (('strategy', 'NN'), 36), (('company', 'NN'), 35), (('building', 'NN'), 35), (('group', 'NN'), 35), (('collection', 'NN'), 33), (('organization', 'NN'), 33), (('part', 'NN'), 33), (('candidate', 'NN'), 32), (('marketing', 'NN'), 32), (('manager', 'NN'), 32), (('andor', 'NN'), 32), (('center', 'NN'), 31), (('database', 'NN'), 30), (('r', 'NN'), 29), (('market', 'NN'), 28), (('python', 'NN'), 27), (('integration', 'NN'), 27), (('job', 'NN'), 26), (('time', 'NN'), 26), (('learning', 'NN'), 26), (('sql', 'NN'), 26), (('reporting', 'NN'), 25), (('york', 'NN'), 25), (('opportunity', 'NN'), 25), (('field', 'NN'), 25), (('industry', 'NN'), 25), (('department', 'NN'), 24), (('computer', 'NN'), 24), (('description', 'NN'), 24), (('level', 'NN'), 24), (('use', 'NN'), 23), (('expertise', 'NN'), 23), (('processing', 'NN'), 23), (('performance', 'NN'), 23), (('customer', 'NN'), 23), (('report', 'NN'), 22), (('variety', 'NN'), 22), (('platform', 'NN'), 21), (('member', 'NN'), 20), (('finance', 'NN'), 20), (('manage', 'NN'), 19), (('office', 'NN'), 19), (('enterprise', 'NN'), 19), (('focus', 'NN'), 19), (('healthcare', 'NN'), 19), (('program', 'NN'), 18), (('access', 'NN'), 18), (('implementation', 'NN'), 18), (('governance', 'NN'), 18), (('entry', 'NN'), 17), (('security', 'NN'), 17), (('application', 'NN'), 17), (('growth', 'NN'), 17), (('life', 'NN'), 17), (('documentation', 'NN'), 16), (('partner', 'NN'), 16), (('analyze', 'NN'), 16), (('environment', 'NN'), 16), (('delivery', 'NN'), 16), (('understanding', 'NN'), 16), (('care', 'NN'), 15), (('leader', 'NN'), 15)]

# %%
top_words_df = pd.DataFrame(top_100_words, columns = ('pos','count'))

# %%
top_words_df.head()
# Out:
#                 pos  count
# 0    (business, NN)    876
# 1     (analyst, NN)    681
# 2  (experience, NN)    253
# 3        (team, NN)    253
# 4    (analysis, NN)    208

# %%
top_words_df['Word'] = top_words_df['pos'].apply(lambda x: x[0]) # split the tuple of POS

# %%
top_words_df = top_words_df.drop('pos', 1) # drop the previous column

# %%
subset_pos = top_words_df[['Word', 'count']]

#tuples_pos = subset_pos.to_dict('split')
tuples_pos = [tuple(x) for x in subset_pos.values]
#tuples_pos=dict((x, y) for y, x in tuples_pos)
subset_pos.head()
# Out:
#          Word  count
# 0    business    876
# 1     analyst    681
# 2  experience    253
# 3        team    253
# 4    analysis    208

# %%
d=dict(tuples_pos)
d['data'] = 4269
d.items()
# Out:
# dict_items([('business', 876), ('analyst', 681), ('experience', 253), ('team', 253), ('analysis', 208), ('engineer', 178), ('machine', 162), ('management', 137), ('support', 134), ('science', 123), ('work', 120), ('scientist', 99), ('join', 98), ('development', 95), ('role', 92), ('process', 74), ('research', 72), ('quality', 72), ('software', 70), ('technology', 70), ('project', 68), ('information', 65), ('product', 65), ('design', 61), ('engineering', 59), ('data', 4269), ('visualization', 55), ('position', 53), ('health', 51), ('detail', 48), ('mining', 46), ('intelligence', 45), ('knowledge', 45), ('ability', 45), ('client', 43), ('help', 37), ('attention', 37), ('system', 36), ('strategy', 36), ('company', 35), ('building', 35), ('group', 35), ('collection', 33), ('organization', 33), ('part', 33), ('candidate', 32), ('marketing', 32), ('manager', 32), ('andor', 32), ('center', 31), ('database', 30), ('r', 29), ('market', 28), ('python', 27), ('integration', 27), ('job', 26), ('time', 26), ('learning', 26), ('sql', 26), ('reporting', 25), ('york', 25), ('opportunity', 25), ('field', 25), ('industry', 25), ('department', 24), ('computer', 24), ('description', 24), ('level', 24), ('use', 23), ('expertise', 23), ('processing', 23), ('performance', 23), ('customer', 23), ('report', 22), ('variety', 22), ('platform', 21), ('member', 20), ('finance', 20), ('manage', 19), ('office', 19), ('enterprise', 19), ('focus', 19), ('healthcare', 19), ('program', 18), ('access', 18), ('implementation', 18), ('governance', 18), ('entry', 17), ('security', 17), ('application', 17), ('growth', 17), ('life', 17), ('documentation', 16), ('partner', 16), ('analyze', 16), ('environment', 16), ('delivery', 16), ('understanding', 16), ('care', 15), ('leader', 15)])

# %%
wordcloud = WordCloud()

# %%
wordcloud.generate_from_frequencies(d)

# %%
plt.figure(figsize=(20,15))
plt.imshow(wordcloud, interpolation="bilinear")

plt.show()

# %%
bgs = nltk.bigrams(tokens)

# %%
fdist2 = nltk.FreqDist(bgs) # selecting bigrams from tokens

# %%
bgs_100 = fdist2.most_common(100) # top-100 bigrams
bgs_df = pd.DataFrame(bgs_100, columns = ('bigram','count'))
bgs_df.head()
# Out:
#                 bigram  count
# 0  (business, analyst)    238
# 1  (machine, learning)    142
# 2      (data, analyst)    139
# 3   (data, scientists)    113
# 4     (data, engineer)    108

# %%
bgs_df['phrase'] = bgs_df['bigram'].apply(lambda x: x[0]+" "+x[1]) # merging the tuple into a string

# %%
punctuation = re.compile(r'[-.?!,":;()|0-9]')
bgs_df['filter_bgs'] = bgs_df['phrase'].str.contains(punctuation) # finding strings with numbers and punctuation

# %%
bgs_df.head()
# Out:
#                 bigram  count            phrase  filter_bgs
# 0  (business, analyst)    238  business analyst       False
# 1  (machine, learning)    142  machine learning       False
# 2      (data, analyst)    139      data analyst       False
# 3   (data, scientists)    113   data scientists       False
# 4     (data, engineer)    108     data engineer       False

# %%
bgs_df = bgs_df[bgs_df.filter_bgs == False] # removing strings with numbers and punctuation

# %%
bgs_df = bgs_df.drop('bigram', 1)
bgs_df = bgs_df.drop('filter_bgs', 1) # removing the excess columns

# %%
bgs_df.reset_index()
bgs_df.head(10) #Final bigrams
# Out:
#    count            phrase
# 0    238  business analyst
# 1    142  machine learning
# 2    139      data analyst
# 3    113   data scientists
# 4    108     data engineer
# 5     96  years experience
# 6     87      data science
# 7     81    data scientist
# 8     77     data analysis
# 9     72    data analytics

# %%
tgs = nltk.ngrams(tokens,4)
fdist3 = nltk.FreqDist(tgs) # selecting trigrams from tokens
tgs_100 = fdist3.most_common(100) # top-100 trigrams
tgs_df = pd.DataFrame(tgs_100, columns = ('trigram','count'))
tgs_df.head()
# Out:
#                                     trigram  count
# 0    (years, experience, business, analyst)     18
# 1       (data, scientists, data, engineers)      9
# 2        (years, experience, working, data)      7
# 3        (years, experience, data, analyst)      6
# 4  (experience, working, business, analyst)      6

# %%
tgs_df['phrase'] = tgs_df['trigram'].apply(lambda x: x[0]+" "+x[1]+" "+x[2])
                                           #+" "+x[3]) # merging the tuple into a string

# %%
tgs_df['filter_tgs'] = tgs_df['phrase'].str.contains(punctuation) # finding strings with numbers and punctuation

# %%
tgs_df.head()
# Out:
#                                     trigram  count  \
# 0    (years, experience, business, analyst)     18
# 1       (data, scientists, data, engineers)      9
# 2        (years, experience, working, data)      7
# 3        (years, experience, data, analyst)      6
# 4  (experience, working, business, analyst)      6
#
#                         phrase  filter_tgs
# 0    years experience business       False
# 1         data scientists data       False
# 2     years experience working       False
# 3        years experience data       False
# 4  experience working business       False

# %%
tgs_df = tgs_df[tgs_df.filter_tgs == False] # removing strings with numbers and punctuation
tgs_df = tgs_df.drop('trigram', 1)
tgs_df = tgs_df.drop('filter_tgs', 1) # removing the excess columns

# %%
tgs_df.reset_index()
tgs_df.head(20) #Final trigrams
# Out:
#     count                       phrase
# 0      18    years experience business
# 1       9         data scientists data
# 2       7     years experience working
# 3       6        years experience data
# 4       6  experience working business
# 5       5          data mining machine
# 6       5         data science machine
# 7       5          data analytics data
# 8       5      closely data scientists
# 10      4       skills ability collect
# 11      4     ability collect organize
# 12      4            data analyst join
# 13      4         data scientists data
# 14      4       years business analyst
# 15      4          data scientist join
# 16      4        machine learning deep
# 17      4          focus applying data
# 18      4         applying data mining
# 19      4       data mining techniques
# 20      4       seeking data scientist

# %%
subset_pos1 = tgs_df[['phrase', 'count']]
tuples_pos1 = [tuple(x) for x in subset_pos1.values]
d4=dict(tuples_pos1)
#d4['data'] = 4269
d4.items()
# Out:
# dict_items([('years experience business', 18), ('data scientists data', 4), ('years experience working', 3), ('years experience data', 3), ('experience working business', 6), ('data mining machine', 5), ('data science machine', 5), ('data analytics data', 5), ('closely data scientists', 5), ('skills ability collect', 4), ('ability collect organize', 4), ('data analyst join', 4), ('years business analyst', 4), ('data scientist join', 3), ('machine learning deep', 4), ('focus applying data', 4), ('applying data mining', 4), ('data mining techniques', 4), ('seeking data scientist', 4), ('provides expertise data', 3), ('expertise data collection', 3), ('data collection design', 3), ('collection design data', 3), ('data analyst responsible', 3), ('experience data analyst', 3), ('collect organize analyze', 3), ('organize analyze disseminate', 3), ('seeking data analyst', 3), ('analytical skills ability', 3), ('analyst intern summer', 3), ('years relevant work', 3), ('senior data analyst', 3), ('data analyst data', 3), ('data analyst business', 3), ('placement assignment level', 3), ('assignment level iv', 3), ('level iv addition', 3), ('iv addition qualification', 3), ('business analyst project', 3), ('project manager business', 3), ('analyst play integral', 3), ('play integral role', 3), ('integral role providing', 3), ('role providing strategic', 3), ('providing strategic recommendations', 3), ('strategic recommendations life', 3), ('looking business analyst', 3), ('business analyst data', 3), ('experience business analyst', 3), ('data scientists machine', 3), ('team data scientists', 3), ('supervised unsupervised machine', 3), ('data scientists product', 3), ('team uses datadriven', 3), ('uses datadriven insights', 3), ('datadriven insights fuel', 3), ('insights fuel strategic', 3), ('mining techniques statistical', 3), ('techniques statistical analysis', 3), ('statistical analysis building', 3), ('analysis building high', 3), ('building high quality', 3), ('high quality prediction', 3), ('subject matter expert', 3), ('data modeling data', 3), ('modeling data access', 3), ('data access data', 3), ('looking senior data', 3), ('senior data engineer', 3), ('three years experience', 3), ('experience working data', 3), ('working data engineer', 3), ('data engineer support', 3), ('engineer support build', 3), ('support build big', 3), ('build big data', 3), ('big data environments', 3), ('data environments enable', 3), ('environments enable analytics', 3), ('enable analytics solutions', 3), ('looking data engineer', 3), ('new york new', 3), ('experienced data engineer', 3), ('data analysts data', 3), ('data scientists software', 3), ('data engineer help', 3), ('years data analyst', 3), ('notforprofit organization partners', 3)])

# %%
wordcloud.generate_from_frequencies(d4)
plt.figure(figsize=(20,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.show()

# %%
# Top data science lang (from KDnuggets) and popu langs from (TIOBE inex)

languages_list = ['R','Python','SAS','SQL','C\\+\\+','C[^+]','Java','Javascript','Scala','C#','Lua','.NET']
tools_list = ['Hadoop','MS Excel','Tableau','Qlik','Spark','Looker','Power BI','Alteryx']
libraries_list = ['ggplot','ggplot2','shiny','dplyr','tensorflow','scikit-learn','pandas','plotly']

skills_dict = {'languages':languages_list,'tools':tools_list,'libraries':libraries_list}
#^ = Not, \w alphaneumeric chars
#java or javascript
# ( space before or after R
# ds['R'] = ds['Job_Description'].str.contains(' R[^\w]', case=False).astype(int)
skills=[]
#should not be a part of a word [^\w]
for j in skills_dict.keys():
    
    for i in range(len(skills_dict[j])):
        i_regex = '[^\w]' + skills_dict[j][i] + '[^\w]'
        ds_main[skills_dict[j][i]] = ds_main['summary'].str.contains(i_regex, case=False).astype(int)
        total_count = sum(ds_main[skills_dict[j][i]])
        skills.append(skills_dict[j][i] + '  ' +  str(total_count))

#Renaming

# This project is DEPRECATED

# %%
type(skills)
# Out:
# list

# %%
str.split(skills[1])
# Out:
# ['Python', '44']

# %%
pd.Series(skills)
# Out:
# 0               R  45
# 1          Python  44
# 2             SAS  13
# 3             SQL  47
# 4            C\+\+  4
# 5           C[^+]  12
# 6             Java  1
# 7       Javascript  0
# 8            Scala  3
# 9               C#  2
# 10             Lua  0
# 11            .NET  0
# 12          Hadoop  9
# 13        MS Excel  2
# 14        Tableau  17
# 15            Qlik  1
# 16           Spark  8
# 17          Looker  0
# 18        Power BI  2
# 19         Alteryx  1
# 20          ggplot  1
# 21         ggplot2  1
# 22           shiny  0
# 23           dplyr  0
# 24      tensorflow  0
# 25    scikit-learn  0
# 26          pandas  3
# 27          plotly  0
# dtype: object

# %%
sk=[]
for d in skills:
    sk2=str.split(d)
    sk.append(sk2)

# %%
sk2=pd.DataFrame.from_records(sk,columns=['lan','oc','x'])

# %%
sk2['lan'][13]='MS Excel'
